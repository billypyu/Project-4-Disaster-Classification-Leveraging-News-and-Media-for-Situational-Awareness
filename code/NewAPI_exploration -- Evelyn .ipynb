# %% [markdown]
# ### Mission: To webscrap news articles from a variety of sources
#
# - Use news API to identify interesting articles
# - Build scrapping code to scrape the articles from the source provided by the news API
# - Store the news articles in a permanent database
# - Process the text of the articles in preparation for NLP
# - Build interesting models around the text to understand sentiment
#
# API source: https://newsapi.org/docs/endpoints/everything

# %%
# !openssl version
# Out:
# OpenSSL 1.1.1a  20 Nov 2018

# %%
import pandas as pd
from datetime import date
import requests
import time
now = time.time()

# %%
def save_news (search_terms,file_name, n_pagesize, start_page, end_pages, save_to_csv): 
    '''
    term_request = which is the key word for search.
    save_to_csv = True indicates csv will be saved
    '''
    
    # API requests
    #for term in search_terms: 
    url = 'https://newsapi.org/v2/everything?'
        
    param = {
    #'country' : 'us',
    'q': search_terms,  #search term 
    'apiKey' : 'e685d6e1420f4882b86d029ed3c1a11d',
    'pageSize': n_pagesize, #max page
    'language': 'en'}
    print (search_terms)
        
    every_term = requests.get(url, params = param)

    articles = every_term.json()['articles'] 
    
    for page in range(start_page, end_pages): #go throught 10 times, and get more pages, 10 more pages
        param['page'] = page
        
        more_term = requests.get(url, params = param)
        more_term = more_term.json()['articles']
        
        articles.extend(more_term)
    arts = pd.DataFrame(articles)
    
    # Drop null and duplicate 
    arts.dropna(inplace=True)
    arts.drop_duplicates(subset='content',inplace = True)
    
    # Creahttp://localhost:8888/notebooks/dsi/Project4_Disaster_Test_Classification/code/NewAPI_exploration.ipynb#te columns
    arts['source_id'] = arts['source'].map(lambda x: x['id'])
    arts['source_name'] = arts['source'].map(lambda x: x['name']) #break up the source, source id, and name colums seperate
    arts.drop (columns = ['source'], axis=1)
    arts['types'] = str(search_terms)
    arts['yes_disaster'] = 1

    # Save df to csv
    if save_to_csv == True: 
        arts.to_csv('../data/'+str(file_name)+'_'+str(search_terms)+'_'+str(now) +'.csv' ,index = False, sep = ",") #index = False for no extra columns
        print (f'{len(articles)} unique news haved been saved')

# %%
list_ev = set(['blizzard', 'storm complex', 'flood', 'snow storm', 'mudflow', 'tornado','Complex fire', 'River floods',
         'earthquake', 'tsunami', 'California wildfires', 'Snow storm','deadlier', 'mph', 'Lake Storm', 'Hurricane Katrina',
         'tornado outbreak', 'ice storm','tsunami', 'tornado', 'blizzard','tremor', 'twister', 'cyclone', 'fire', 'lightning', 
         'hurricane', 'whirlpool', 'cloud', 'gale', 'force', 'snowstorm', 'nimbus', 'casualty', 'fatality', 'lost', 
         'tension', 'uproot', 'arsonist', 'rescue', 'fault', 'Natural disasters', 'avalanche', 'drought','dust storm'])

# %%
keyword_for_terrorism = []

# %%
list_final = list(list_ev)

# %%
len(list_final)
# Out:
# 42

# %%
for item in list_final: 
    save_news (item, file_name ='e', n_pagesize=10, start_page=2, end_pages=25, save_to_csv=True)
#save_news (['disaster'], file_name ='b', n_pagesize=10, start_page=2, end_pages=3, save_to_csv=True)
# Out:
# earthquake
# 240 unique news haved been saved
# snowstorm
# 240 unique news haved been saved
# lightning
# 240 unique news haved been saved
# Complex fire
# 240 unique news haved been saved
# Hurricane Katrina
# 240 unique news haved been saved
# hurricane
# 240 unique news haved been saved
# uproot
# 240 unique news haved been saved
# ice storm
# 240 unique news haved been saved
# tornado outbreak
# 240 unique news haved been saved
# fire
# 240 unique news haved been saved
# mph
# 240 unique news haved been saved
# storm complex
# 240 unique news haved been saved
# drought
# 240 unique news haved been saved
# cyclone
# 240 unique news haved been saved
# whirlpool
# 240 unique news haved been saved
# blizzard
# 240 unique news haved been saved
# dust storm
# 240 unique news haved been saved
# casualty
# 240 unique news haved been saved
# nimbus
# 240 unique news haved been saved
# fatality
# 240 unique news haved been saved
# tension
# 240 unique news haved been saved
# fault
# 240 unique news haved been saved
# tornado
# 240 unique news haved been saved
# lost
# 240 unique news haved been saved
# California wildfires
# 240 unique news haved been saved
# gale
# 240 unique news haved been saved
# Natural disasters
# 240 unique news haved been saved
# arsonist
# 240 unique news haved been saved
# tsunami
# 240 unique news haved been saved
# River floods
# 240 unique news haved been saved
# cloud
# 240 unique news haved been saved
# force
# 240 unique news haved been saved
# Lake Storm
# 240 unique news haved been saved
# deadlier
# 240 unique news haved been saved
# mudflow
# 240 unique news haved been saved
# rescue
# 240 unique news haved been saved
# Snow storm
# 240 unique news haved been saved
# flood
# 240 unique news haved been saved
# avalanche
# 240 unique news haved been saved
# tremor
# 240 unique news haved been saved
# snow storm
# 240 unique news haved been saved
# twister
# 240 unique news haved been saved

# %%
# !pwd
# Out:
# /Users/evelyn/Documents/DSI/project_4/Project-4-Disaster-Classification/code

# %%
path+ "/e_*.csv"
# Out:
# '/Users/evelyn/Documents/DSI/project_4/Project-4-Disaster-Classification/code/e_*.csv'

# %%
#Code reference stack overflow 
#merge all files together 
import glob

all_files = glob.glob("../data/e_*.csv")

lst = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    lst.append(df)

df = pd.concat(lst, axis=0, ignore_index=True)

# %%
#df= pd.read_csv('../data/b_Harvey_1555193272.906144.csv')
df.columns
# Out:
# Index(['author', 'content', 'description', 'publishedAt', 'source', 'title',
#        'url', 'urlToImage', 'source_id', 'source_name', 'types',
#        'yes_disaster'],
#       dtype='object')

# %%
df.shape
# Out:
# (8744, 12)

# %%
df_title = df[['title', 'yes_disaster']]

# %%
df_title.to_csv('../data/e_title_only.csv')

# %%
df_title.shape
# Out:
# (8744, 2)

# %%
df_title.drop_duplicates()
# Out:
#                                                   title  yes_disaster
# 0     FilmStruck Is the Latest Casualty of the Strea...             1
# 1     news analysis: We’re All Stuck Inside George a...             1
# 2     Belgian Prime Minister, Facing Populist Revolt...             1
# 3     Back-to-School Shopping for Districts: Armed G...             1
# 4     White House Says ‘Horrific, Tragic’ Death of M...             1
# 5     Chief Security Officer Alex Stamos is leaving ...             1
# 6     The Death Toll for Afghan Forces Is Secret. He...             1
# 7     People hospitalized after Missouri tourist boa...             1
# 8     China’s third-largest bike sharing service, wh...             1
# 9          How to Avoid the Most Common Moving Mistakes             1
# 10    LittleThings blames its shutdown on Facebook a...             1
# 11    Google Kills Allo in Latest Attempt to Fix Its...             1
# 12    Another Defender bites the dust as Netflix can...             1
# 13    Terrifying images emerge after Southwest plane...             1
# 14    Russia's Telegram ban is causing problems for ...             1
# 15    Passengers stranded after Iceland's WOW air co...             1
# 16    At War: My Husband Was Killed in Niger. His De...             1
# 17    ‘We’re in Uncharted Waters.’ Schools Brace for...             1
# 18    Fyre Festival founder Billy McFarland settles ...             1
# 19             Inverted jeans are here to ruin your day             1
# 20         Sphero is finished making Star Wars products             1
# 21    MGM Resorts Sues 1,000 Victims of Las Vegas Sh...             1
# 22    Cushy hotel rooms and fussy amenities in luxur...             1
# 23    Santa Fe High School: 'Multiple fatalities' re...             1
# 24    IED blast in Kashmir, 4km from Pulwama terror ...             1
# 25    IAF air strikes: Defence minister says Centre ...             1
# 26              Guy Fieri Says Farewell to Times Square             1
# 27    Asian Markets Offer Hope for End to Global Sto...             1
# 28    Taliban Kill Police Officers, Including a Chie...             1
# 29    Yes, glitter's fun. But, it could land you in ...             1
# ...                                                 ...           ...
# 8707           Nicaraguans scared of end of protections             1
# 8708  Japanese Broadcaster Mistakenly Warns App User...             1
# 8710  Watching a Ridge Slide in Slow Motion, a Town ...             1
# 8711  Contributing Op-Ed Writer: No One Is Coming to...             1
# 8712  John Bolton just fired Trump's top homeland se...             1
# 8713  Earth just hit a terrifying milestone for the ...             1
# 8714   At Least 179 Dead in Japan’s Calamitous Flooding             1
# 8716  U.S. disaster-response force stretched thin as...             1
# 8717  Just Five Countries Hold Most of the World’s R...             1
# 8718  Lawmaker sorry for spreading anti-Semitic weat...             1
# 8719                          PERSONAL MESH NETWORKING:             1
# 8720  Robotic noses could be the future of disaster ...             1
# 8721  Study finds that false news spreads faster tha...             1
# 8722  How This Entrepreneur Bounced Back After Losin...             1
# 8723  Natural disasters leave their mark on kids who...             1
# 8724  Scientists Prove That Truth is No Match For Fi...             1
# 8725  Fact Check of the Day: Checking 6 Claims From ...             1
# 8726          What are the biggest threats to humanity?             1
# 8727  17 things you're paying for that you can actua...             1
# 8729  The Wall Street Journal: Natural disasters too...             1
# 8730  In One Chart: 2017 was the costliest year ever...             1
# 8733  Beyoncé is worth $355 million — see how she sp...             1
# 8734  Trump’s Homeland Security Adviser Tom Bossert ...             1
# 8735  New Yorkers Sue Trump and FEMA To Stop Preside...             1
# 8736  Video Shows Animals Stranded by Hurricane Flor...             1
# 8738  California’s Camp Fire Was The Most Expensive ...             1
# 8739  4 Fool-Proof Ways to Stay Centered When Life I...             1
# 8741  Mattis says the Pentagon will build temporary ...             1
# 8742  Official near-earth object plan will look into...             1
# 8743  Airbnb will now let people register as Open Ho...             1
#
# [7243 rows x 2 columns]

# %%
df.to_csv('../data/e_all_keyword_list.csv')

# %%
df.head()
# Out:
#                            author  \
# 0                   Brian Raftery
# 1                  MARK LEIBOVICH
# 2  MATT APUZZO and MILAN SCHREUER
# 3                 PATRICIA MAZZEI
# 4                       RON NIXON
#
#                                              content  \
# 0  Early on Friday, WarnerMedia announced it was ...
# 1  Politics has always loved a good odd-couple st...
# 2  The agreement has recently become a flash poin...
# 3  “There were opportunities for the staff to hav...
# 4  Around 6:30 a.m., officials said, Jakelin bega...
#
#                                          description           publishedAt  \
# 0  The AT&T/Time Warner merger has claimed anothe...  2018-10-26T19:12:28Z
# 1  Are we watching a life partnership fracture on...  2019-03-30T18:30:01Z
# 2  A government collapse would be a high-profile ...  2018-12-18T21:36:47Z
# 3  The shooting in Parkland, Fla., spurred school...  2018-08-11T15:18:34Z
# 4  A 7-year-old Guatemalan girl died from dehydra...  2018-12-14T20:00:29Z
#
#                                               source  \
# 0                   {'id': 'wired', 'name': 'Wired'}
# 1  {'id': 'the-new-york-times', 'name': 'The New ...
# 2  {'id': 'the-new-york-times', 'name': 'The New ...
# 3  {'id': 'the-new-york-times', 'name': 'The New ...
# 4  {'id': 'the-new-york-times', 'name': 'The New ...
#
#                                                title  \
# 0  FilmStruck Is the Latest Casualty of the Strea...
# 1  news analysis: We’re All Stuck Inside George a...
# 2  Belgian Prime Minister, Facing Populist Revolt...
# 3  Back-to-School Shopping for Districts: Armed G...
# 4  White House Says ‘Horrific, Tragic’ Death of M...
#
#                                                  url  \
# 0  https://www.wired.com/story/rip-filmstruck-str...
# 1  https://www.nytimes.com/2019/03/30/sunday-revi...
# 2  https://www.nytimes.com/2018/12/18/world/europ...
# 3  https://www.nytimes.com/2018/08/11/us/back-to-...
# 4  https://www.nytimes.com/2018/12/14/us/politics...
#
#                                           urlToImage           source_id  \
# 0  https://media.wired.com/photos/5bd365c6189fdd7...               wired
# 1  https://static01.nyt.com/images/2019/03/31/opi...  the-new-york-times
# 2  https://static01.nyt.com/images/2018/12/19/wor...  the-new-york-times
# 3  https://static01.nyt.com/images/2018/08/12/us/...  the-new-york-times
# 4  https://static01.nyt.com/images/2018/12/15/us/...  the-new-york-times
#
#           source_name     types  yes_disaster
# 0               Wired  casualty             1
# 1  The New York Times  casualty             1
# 2  The New York Times  casualty             1
# 3  The New York Times  casualty             1
# 4  The New York Times  casualty             1

# %% [markdown]
# ---

# %%
#Combind rows 
df2 = pd.read_csv('../data/Evelyn_csv_data/e_title_list.csv')

# %%
df2['yes_disaster'].value_counts()
# Out:
# 0    6224
# 1    2520
# Name: yes_disaster, dtype: int64

# %%
df3 = pd.read_csv('../data/Evelyn_csv_data/e_all_keyword_list.csv')

# %%
df3['yes_disaster'].value_counts()
# Out:
# 1    8744
# Name: yes_disaster, dtype: int64

# %%
df3['yes_disaster'] = df2['yes_disaster']

# %%
df3['yes_disaster'].value_counts()
# Out:
# 0    6224
# 1    2520
# Name: yes_disaster, dtype: int64

# %%
df3.drop(columns = 'Unnamed: 0', inplace = True)

# %%
df3.head()
# Out:
#                            author  \
# 0                   Brian Raftery
# 1                  MARK LEIBOVICH
# 2  MATT APUZZO and MILAN SCHREUER
# 3                 PATRICIA MAZZEI
# 4                       RON NIXON
#
#                                              content  \
# 0  Early on Friday, WarnerMedia announced it was ...
# 1  Politics has always loved a good odd-couple st...
# 2  The agreement has recently become a flash poin...
# 3  “There were opportunities for the staff to hav...
# 4  Around 6:30 a.m., officials said, Jakelin bega...
#
#                                          description           publishedAt  \
# 0  The AT&T/Time Warner merger has claimed anothe...  2018-10-26T19:12:28Z
# 1  Are we watching a life partnership fracture on...  2019-03-30T18:30:01Z
# 2  A government collapse would be a high-profile ...  2018-12-18T21:36:47Z
# 3  The shooting in Parkland, Fla., spurred school...  2018-08-11T15:18:34Z
# 4  A 7-year-old Guatemalan girl died from dehydra...  2018-12-14T20:00:29Z
#
#                                               source  \
# 0                   {'id': 'wired', 'name': 'Wired'}
# 1  {'id': 'the-new-york-times', 'name': 'The New ...
# 2  {'id': 'the-new-york-times', 'name': 'The New ...
# 3  {'id': 'the-new-york-times', 'name': 'The New ...
# 4  {'id': 'the-new-york-times', 'name': 'The New ...
#
#                                                title  \
# 0  FilmStruck Is the Latest Casualty of the Strea...
# 1  news analysis: We’re All Stuck Inside George a...
# 2  Belgian Prime Minister, Facing Populist Revolt...
# 3  Back-to-School Shopping for Districts: Armed G...
# 4  White House Says ‘Horrific, Tragic’ Death of M...
#
#                                                  url  \
# 0  https://www.wired.com/story/rip-filmstruck-str...
# 1  https://www.nytimes.com/2019/03/30/sunday-revi...
# 2  https://www.nytimes.com/2018/12/18/world/europ...
# 3  https://www.nytimes.com/2018/08/11/us/back-to-...
# 4  https://www.nytimes.com/2018/12/14/us/politics...
#
#                                           urlToImage           source_id  \
# 0  https://media.wired.com/photos/5bd365c6189fdd7...               wired
# 1  https://static01.nyt.com/images/2019/03/31/opi...  the-new-york-times
# 2  https://static01.nyt.com/images/2018/12/19/wor...  the-new-york-times
# 3  https://static01.nyt.com/images/2018/08/12/us/...  the-new-york-times
# 4  https://static01.nyt.com/images/2018/12/15/us/...  the-new-york-times
#
#           source_name     types  yes_disaster
# 0               Wired  casualty             0
# 1  The New York Times  casualty             0
# 2  The New York Times  casualty             0
# 3  The New York Times  casualty             0
# 4  The New York Times  casualty             0

# %%
df3.to_csv('../data/consolidate_data/e_consolidated_4_18_2019.csv')

# %%
df3['yes_disaster'].unique()
# Out:
# array([0, 1])
